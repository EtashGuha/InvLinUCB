# %%
import numpy as np
import math
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
from scipy.stats import truncnorm
import copy
from sklearn.metrics import mean_squared_error

# %%
class LinUCB():
    def __init__(self, arm, dim=2, lamda = 1, T=1000):
        self.arm = arm
        self.A_t = 0
        self.y = np.matrix(np.zeros((dim, 1)))
        self.V = np.matrix(lamda * np.identity(dim))
        self.lamda = lamda
        self.beta =  1 + np.sqrt(2*np.log(T)+dim*np.log((dim+T)/dim))
        self.actions = []
        self.T = T
        self.dim = dim
        self.action_idxs = []
        self.Vs = [copy.deepcopy(self.V)]
    def observe_reward(self, reward):
        
        self.V = self.V + self.arm[self.A_t].T * self.arm[self.A_t]
        self.Vs.append(copy.deepcopy(self.V))
        self.y = self.y + self.arm[self.A_t].T * reward
        
        
    def compute(self):
        inv_V = np.linalg.inv(self.V)
        self.hat_theta = inv_V * self.y
        ucb = self.arm * self.hat_theta + self.beta * np.matrix(np.diag(np.sqrt( self.arm * inv_V * self.arm.T ))).T
        self.A_t = np.argmax(ucb)
        self.actions.append(self.arm[self.A_t])
        self.action_idxs.append(self.A_t)
        return self.arm[self.A_t]

# %%
class UCB:
    def __init__(self, action_set, dim=2, T=1000):
        self.arm = action_set
        self.T = T
        self.alpha = 1/(T**2)
        self.sample_means = np.asarray([0.0] * len(action_set))
        self.confidence_widths = np.asarray([np.inf] * len(action_set))
        self.num_pulls = np.asarray([0] * len(action_set))
        self.actions = []
        self.action_idxs = []
        self.counter = 0
        self.debug_mean = {}
        self.debug_cw = {}
        self.debug_np = {}
        
    def compute(self):
        
        if self.counter < len(action_set):
            index = self.counter
        else:
            index = np.argmax(self.sample_means + self.confidence_widths)
        
        self.debug_mean[self.counter] = copy.deepcopy(self.sample_means)
        self.debug_cw[self.counter] = copy.deepcopy(self.confidence_widths)
        self.debug_np[self.counter] = copy.deepcopy(self.num_pulls)
        self.counter += 1
        self.num_pulls[index] += 1
        
        self.action_idxs.append(index)
        self.actions.append(self.arm[index])
        return self.arm[index]
    
    def observe_reward(self, reward):
        
        cur_mean = self.sample_means[self.action_idxs[-1]]
        num_samples = self.num_pulls[self.action_idxs[-1]] - 1
        new_mean = (cur_mean * num_samples + reward)/(num_samples + 1)
        self.sample_means[self.action_idxs[-1]] = new_mean
        self.confidence_widths[self.action_idxs[-1]] = self.gcb(self.T, self.alpha, num_samples + 1)
        
    @staticmethod
    def gcb(T, alpha, num_samples):
        return np.sqrt(2*(math.pow(T, alpha) - 1)/(alpha * num_samples))

# %%
def calc_pseudoregret(theta, actions):
    diff = theta - np.max(theta)
    new_actions = np.stack(actions, axis=0)
    return -np.sum(np.dot(new_actions, theta))

# %%
class Oracle:
    def __init__(self, theta, upper=1, lower=0):
        self.theta = theta
        self.upper = upper
        self.lower = lower
        
    def compute_reward(self, action):
        mu = np.inner(action, self.theta)
        sigma = .2
        X = truncnorm((self.lower - mu) / sigma, (self.upper - mu) / sigma, loc=mu, scale=sigma)
        return X.rvs(1)[0]

# %%
def train_alg(alg, T, theta, oracle):
    alg.actions = [0]
    reward = oracle.compute_reward(alg.arm[0])
    alg.observe_reward(reward)
    for time in range(T):
        action = alg.compute()
        reward = oracle.compute_reward(action)
        alg.observe_reward(reward)
        
def train_alg_UCB(alg, T, theta, oracle):
    for time in range(T):
        action = alg.compute()
        reward = oracle.compute_reward(action)
        alg.observe_reward(reward)

# %%
def generate_k_dim_vector(dim=2):
    full_index = random.randint(0,dim-1)
    vec = np.random.random(int(dim)) * 2 - 1
    vec[full_index] = np.sign(vec[full_index]) * 1
    return vec

def generate_random_vec(dim=2, mag=1):
    vec = np.random.random(int(dim))
    vec = vec/np.linalg.norm(vec)*mag
    return vec

# %%
def plot_vectors(theta, actions):
    plt.axis([-1, 1, -1, 1])
    plt.quiver(0, 0, theta[0], theta[1], color='green', scale=1)
    for idx, action in enumerate(actions):
        plt.quiver(0, 0, action[0], action[1], color = [(idx/len(actions), 0, 0)], scale=1)

# %%
x = np.linspace(0,1,11)
y = np.linspace(1,0,11)
u = v = np.zeros((11,11))
u[5,5] = 0.2
plt.axis('equal')
plt.axis([-1, 1, -1, 1])
plt.quiv
er(0,0, .8, -.33,  color=[(.5, 0, 0)], scale=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_5879/467216575.py in <module>
#       5 plt.axis('equal')
#       6 plt.axis([-1, 1, -1, 1])
# ----> 7 plt.quiv
#       8 er(0,0, .8, -.33,  color=[(.5, 0, 0)], scale=1)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'quiv'

# %%
#Change action set to boundaries
#Check how two thetas with same optimal actions will have different action sequences
#Why are these different? How will these differ?
#Choose different colors and figure out the scale
#check about frequency of "pulls", sum the action sequence!
#Candidate values of theta: alternating signs (like with 0.9, 0.5 as values, a lot of coordinates should differ), alternating signs with only one coord differs
#Exploratory: If you were just solving mab, can you formulat an alternative estimator that is a solution to an lp
#Exploratory: decision variables are unknown means where you have to solve, and every time an arm is pulled, you get a constraint
# You also get other constraints that when an arm is not pulled, you get an equality constraint
#so look at the end of the horizon, and get the lp from there

# %%
import gurobipy as gp

def estimate_ucb_means_lp(alg):
    m = gp.Model()
    all_vars = {}
    num_pulls = {}
    T = alg.T
    for i in range(len(action_set)):
        num_pulls[i] = []

    for t in range(T):
        for key in num_pulls.keys():
            if alg.action_idxs[t] != key:
                if t != 0:
                    num_pulls[key].append(num_pulls[key][ - 1])
                else:
                    num_pulls[key].append(0)
            else:
                if t != 0:
                    num_pulls[key].append(num_pulls[key][ - 1] + 1)
                else:
                    num_pulls[key].append(1)

    for t in range(T):
        for idx, ele in enumerate(action_set):
            if t not in all_vars:
                all_vars[t] = {}
            all_vars[t][idx] = m.addVar(name="u_{}_{}".format(t, idx))

    expr = gp.LinExpr()
    list_of_all_vars = []
    for t in range(T-1,T):
        for i in range(len(action_set)):
            list_of_all_vars.append(all_vars[t][i])

    
    expr.addTerms([1.0] * len(list_of_all_vars), list_of_all_vars)

    m.setObjective(expr, gp.GRB.MAXIMIZE)



    for t, ele in enumerate(alg.action_idxs):
        for i in range(len(action_set)):
            if i != ele and t >= len(action_set):
                m.addConstr(all_vars[t][ele] + UCB.gcb(T, alg.alpha, num_pulls[ele][t-1]) - all_vars[t][i] - UCB.gcb(T, alg.alpha, num_pulls[i][t - 1]) >= 0)
                if t + 1 < T:
                    m.addConstr(all_vars[t + 1][i] - all_vars[t][i] == 0)
            m.addConstr(all_vars[t][i] >= 0)
            m.addConstr(all_vars[t][i] <= 1)



    m.optimize()
    lp_vals = []
    for i in range(len(action_set)):
        lp_vals.append(all_vars[T-1][i].X)
        
    return lp_vals

# %%
def calc_Vs(alg):
    Vs = []
    Vs.append(alg.lamda * np.identity(alg.dim))
    for t in range(T):
        Vs.append(Vs[-1] + (alg.actions[t].T * alg.actions[t]))
    return(Vs)

def estimate_linucb_means_lp(alg, normalize=True):
    m = gp.Model()
    all_vars = {}
    T = alg.T
    
    Vs = calc_Vs(alg)
    for t in range(T):
        all_vars[t] = []
        for i in range(dim):
            all_vars[t].append(m.addVar(name="y_{}_{}".format(t, idx)))
    
    expr = gp.LinExpr()
    expr.addTerms([1.0] * len(all_vars[alg.T - 1]),all_vars[alg.T - 1])
    
    m.setObjective(expr, gp.GRB.MAXIMIZE) 
    for t in range(T):
        for action in action_set:
            V = Vs[t]
            invV = np.linalg.inv(V)
            if action is not alg.actions[t]:
                expr = gp.LinExpr()
                
                mult = np.asarray(action @ invV)[0] * -1
                expr.addTerms(mult, all_vars[t])
                constant = np.sqrt(action @ invV @ action.T) * alg.beta * -1
                expr.addConstant(constant)
                          
                opt_mult = np.asarray(alg.actions[t] @ invV)[0]
                expr.addTerms(opt_mult, all_vars[t])
                opt_constant = np.sqrt(alg.actions[t] @ invV @ alg.actions[t].T) * alg.beta
                expr.addConstant(opt_constant)
                
                m.addConstr(expr >= 0)
    
    for i in range(alg.dim):
        m.addConstr(all_vars[0][i] == 0)
                
                
    
    for i in range(alg.dim):
        for t in range(alg.T):
            if t + 1 < alg.T:
                m.addConstr(all_vars[t][i] + 1 >= all_vars[t + 1][i])
                m.addConstr(all_vars[t][i] <= all_vars[t+1][i])

    m.optimize()
            
    final_Vinv = np.linalg.inv(Vs[-1])
    final_y = np.matrix([ele.X for ele in all_vars[alg.T - 1]]).T
    
    
    theta_estimate = np.linalg.inv(Vs[-1]) @ np.matrix(final_y)
    
    if normalize:
        theta_estimate = theta_estimate/np.linalg.norm(theta_estimate)
    return theta_estimate

# %%
def test_UCB(theta, action_set, T=1000):
    dim = theta.shape[-1]
    oracle = Oracle(theta)
    alg = UCB(action_set, T=T, dim=dim)
    train_alg_UCB(alg, T, theta, oracle)
    
    lp_vals = estimate_ucb_means_lp(alg)
    best_lp = max(lp_vals)
    lp_vals_subopt = best_lp - np.asarray(lp_vals)
                    
    best_sample = max(alg.sample_means)
    alg_sample_subopt = best_sample - alg.sample_means
    return mean_squared_error(alg_sample_subopt, lp_vals_subopt)
    
def test_LinUCB(theta, action_set, T=1000):
    oracle = Oracle(theta)
    dim = theta.shape[-1]
    alg = LinUCB(action_set, dim=dim, T=T)
    train_alg_UCB(alg, T, theta, oracle)
    
    theta_estimate = estimate_linucb_means_lp(alg)
    return mean_squared_error(theta, theta_estimate.T)

# %%
Ts = [10, 50, 100, 500, 1000, 2000]
NumArmss = [2, 5, 10, 20, 50, 100]
num_epochs = 10
ucb_errors = {}
linucb_errors = {}
for T in Ts:
    ucb_errors[T] = {}
    linucb_errors[T] = {}
    for num_arms in NumArmss:
        ucb_errors[T][num_arms] = []
        linucb_errors[T][num_arms] = []
        for _ in range(num_epochs):
            theta = np.matrix(generate_random_vec(dim = 2))
            action_set = np.matrix([generate_random_vec(dim = 2) for _ in range(num_arms)])
            ucb_error = test_UCB(theta, action_set, T=T)
            lin_ucb_error = test_LinUCB(theta, action_set, T=T)
            linucb_errors[T][num_arms].append(lin_ucb_error)
            ucb_errors[T][num_arms].append(ucb_error)
# Out:
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0x4e7dd38d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7191158e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.719115780e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0xa39f68a8
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 34 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 32 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3379140e+01   1.218154e+01   0.000000e+00      0s
#       20    1.5064833e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 20 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.506483276e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0x1dbe6eea
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8860670e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.886066951e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0x7901dc19
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 35 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 23 rows, 32 columns, 61 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6387863e+01   8.276129e+00   0.000000e+00      0s
#       23    1.6156080e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 23 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.615608012e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0x0d28503c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0x98324a07
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 34 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 32 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7883156e+01   8.108980e+00   0.000000e+00      0s
#       19    1.5243250e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 19 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.524325033e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0x78c2ef9d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8860670e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.886066951e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0xb3654c68
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 35 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 23 rows, 31 columns, 60 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8019000e+01   9.347124e+00   0.000000e+00      0s
#       15    1.7345836e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.734583575e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0x96c80630
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8860670e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.886066951e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0xa1540b6a
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 35 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 23 rows, 31 columns, 60 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8019000e+01   9.271860e+00   0.000000e+00      0s
#       18    1.5615717e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 18 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.561571659e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0x1dbe6eea
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8860670e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.886066951e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0x184208cc
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-02, 1e+00]
# Presolve removed 35 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 23 rows, 31 columns, 60 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7211015e+01   8.733609e+00   0.000000e+00      0s
#       18    1.7193437e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 18 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.719343668e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0x80e4d363
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0x89575748
# Coefficient statistics:
#   Matrix range     [2e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 35 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 23 rows, 32 columns, 61 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6997665e+01   8.731433e+00   0.000000e+00      0s
#       22    1.6981070e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 22 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.698106976e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0xc7dd24e6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0x1380cefc
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Presolve removed 34 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 24 rows, 32 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8019000e+01   4.858870e+00   0.000000e+00      0s
#       23    1.6418378e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 23 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.641837843e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0x38a07121
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8860670e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.886066951e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0x5b6437ea
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 34 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 32 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9757008e+00   2.000031e+00   0.000000e+00      0s
#       14    9.9657582e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.965758234e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 55 rows, 20 columns and 70 nonzeros
# Model fingerprint: 0xc7dd24e6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 55 rows and 20 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 58 rows, 20 columns and 94 nonzeros
# Model fingerprint: 0x1a5becb1
# Coefficient statistics:
#   Matrix range     [4e-02, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-03, 1e+00]
# Presolve removed 34 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 24 rows, 32 columns, 63 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8019000e+01   5.261507e+00   0.000000e+00      0s
#       19    1.7305306e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 19 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.730530583e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 136 rows, 50 columns and 172 nonzeros
# Model fingerprint: 
+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 25 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.059441708e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 200 rows, 100 columns and 200 nonzeros
# Model fingerprint: 0x997ef546
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 200 rows and 100 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 138 rows, 20 columns and 254 nonzeros
# Model fingerprint: 0xae706d52
# Coefficient statistics:
#   Matrix range     [3e-02, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Presolve removed 51 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 87 rows, 32 columns, 189 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5607355e+01   3.518829e+00   0.000000e+00      0s
#       24    1.3767858e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 24 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.376785778e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 200 rows, 100 columns and 200 nonzeros
# Model fingerprint: 0x997ef546
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 200 rows and 100 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 138 rows, 20 columns and 254 nonzeros
# Model fingerprint: 0x84bf6ff2
# Coefficient statistics:
#   Matrix range     [1e-02, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-02, 1e+00]
# Presolve removed 51 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 87 rows, 32 columns, 189 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9338343e+01   4.360245e+00   0.000000e+00      0s
#       19    1.7646916e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 19 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.764691623e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 200 rows, 100 columns and 200 nonzeros
# Model fingerprint: 0x997ef546
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 200 rows and 100 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 138 rows, 20 columns and 254 nonzeros
# Model fingerprint: 0x663e2230
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Presolve removed 57 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 81 rows, 32 columns, 177 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6390280e+01   7.796529e+00   0.000000e+00      0s
#       15    1.4322416e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.432241556e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 200 rows, 100 columns and 200 nonzeros
# Model fingerprint: 0x997ef546
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 200 rows and 100 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 138 rows, 20 columns and 254 nonzeros
# Model fingerprint: 0x97fb6908
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Presolve removed 50 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 88 rows, 32 columns, 191 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6136826e+01   5.072912e+00   0.000000e+00      0s
#       25    1.0328057e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 25 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.032805660e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 400 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xb777cd1f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 400 rows and 200 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.000000000e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 238 rows, 20 columns and 454 nonzeros
# Model fingerprint: 0x38e3255d
# Coefficient statistics:
#   Matrix range     [2e-03, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Presolve removed 70 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 168 rows, 34 columns, 352 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8020000e+01   3.032865e+00   0.000000e+00      0s
#       28    1.2073360e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 28 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.207336011e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 400 rows, 200 columns and 400 nonzeros
# Model fingerprint: 0xb777cd1f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 400 rows and 200 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.000000000e+01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 238 rows, 20 columns and 454 nonzeros
# Model fingerprint: 0x4922cc2a
# Coefficient statistics:
#   Matrix range     [3e-03, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Presolve removed 74 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 164 rows, 31 columns, 342 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# ...
#        0 DPushes remaining with DInf 0.0000000e+00                 1s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 1s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3944179e-11      1s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3991    2.1602943e+03   0.000000e+00   0.000000e+00      2s
#
# Solved with barrier
# Solved in 3991 iterations and 1.70 seconds (1.09 work units)
# Optimal objective  2.160294253e+03
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 776101 rows, 200000 columns and 1152202 nonzeros
# Model fingerprint: 0xaf029273
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 776101 rows and 200000 columns
# Presolve time: 0.53s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.9927324e+01   0.000000e+00   0.000000e+00      1s
#
# Solved with dual simplex
# Solved in 0 iterations and 0.92 seconds (0.50 work units)
# Optimal objective  8.992732406e+01
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_5879/1805981238.py:25: RuntimeWarning: invalid value encountered in sqrt
#   ucb = self.arm * self.hat_theta + self.beta * np.matrix(np.diag(np.sqrt( self.arm * inv_V * self.arm.T ))).T
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 207998 rows, 4000 columns and 411994 nonzeros
# Model fingerprint: 0x1dcc596a
# Coefficient statistics:
#   Matrix range     [4e-06, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 2e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 6238 rows and 2 columns
# Presolve removed 2 rows and 5340 columns
# Presolve time: 0.91s
# Presolved: 3998 rows, 202658 columns, 405314 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.994e+03
#  Factor NZ  : 6.787e+04 (roughly 80 MB of memory)
#  Factor Ops : 1.432e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.12225076e+06  1.54450448e+03  8.27e+01 1.32e+01  5.62e+01     1s
#    1  -2.05621884e+05  2.28045527e+03  2.17e+01 3.23e+01  2.31e+01     1s
#    2   2.55249342e+05  2.45011772e+03  2.13e-12 1.15e+01  8.18e+00     1s
#    3   1.46762098e+05  2.21348234e+03  3.89e-11 2.95e+00  2.11e+00     1s
#    4   7.74616596e+04  2.18831478e+03  7.08e-12 1.23e+00  7.86e-01     1s
#    5   6.09315600e+04  2.18217050e+03  4.80e-12 4.50e-01  4.20e-01     1s
#    6   3.38806678e+04  2.18260565e+03  1.95e-12 1.79e-01  1.88e-01     1s
#    7   1.17794265e+04  2.18597593e+03  3.82e-13 5.71e-02  5.12e-02     1s
#    8   6.18537703e+03  2.19041729e+03  2.20e-12 2.91e-02  2.06e-02     1s
#    9   3.91484235e+03  2.19308052e+03  2.05e-12 1.93e-02  8.77e-03     1s
#   10   2.35102391e+03  2.19184670e+03  5.72e-13 2.84e-13  7.85e-04     1s
#   11   2.19819036e+03  2.19284209e+03  1.63e-12 2.97e-13  2.64e-05     1s
#   12   2.19285199e+03  2.19284664e+03  7.95e-12 2.84e-13  2.64e-08     1s
#   13   2.19284665e+03  2.19284665e+03  6.18e-12 2.84e-13  2.65e-14     1s
#
# Barrier solved model in 13 iterations and 1.45 seconds (1.00 work units)
# Optimal objective 2.19284665e+03
#
# Crossover log...
#
#     3993 DPushes remaining with DInf 0.0000000e+00                 1s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.6730623e-12      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3992    2.1928467e+03   0.000000e+00   0.000000e+00      2s
#
# Solved with barrier
# Solved in 3992 iterations and 1.81 seconds (1.11 work units)
# Optimal objective  2.192846651e+03
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 776101 rows, 200000 columns and 1152202 nonzeros
# Model fingerprint: 0x3a3124e9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 776101 rows and 200000 columns
# Presolve time: 0.53s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.3752374e+01   0.000000e+00   0.000000e+00      1s
#
# Solved with dual simplex
# Solved in 0 iterations and 0.92 seconds (0.50 work units)
# Optimal objective  9.375237418e+01
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_5879/1805981238.py:25: RuntimeWarning: invalid value encountered in sqrt
#   ucb = self.arm * self.hat_theta + self.beta * np.matrix(np.diag(np.sqrt( self.arm * inv_V * self.arm.T ))).T
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 207998 rows, 4000 columns and 411994 nonzeros
# Model fingerprint: 0x71ca4528
# Coefficient statistics:
#   Matrix range     [5e-06, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 6277 rows and 2 columns
# Presolve removed 2 rows and 3048 columns
# Presolve time: 1.06s
# Presolved: 3998 rows, 204950 columns, 409898 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.995e+03
#  Factor NZ  : 6.787e+04 (roughly 80 MB of memory)
#  Factor Ops : 1.432e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -1.32610285e+06  1.69686598e+03  7.81e+01 9.56e+00  4.63e+01     1s
#    1  -3.89861213e+05  2.37048985e+03  2.85e+01 2.55e+01  2.15e+01     1s
#    2   2.72963028e+05  2.50473919e+03  1.95e-01 1.34e+01  1.08e+01     1s
#    3   1.77873687e+05  2.23887898e+03  2.02e-12 2.81e+00  2.46e+00     1s
#    4   8.01584840e+04  2.21733468e+03  2.87e-12 1.00e+00  7.47e-01     1s
#    5   4.81839992e+04  2.21323613e+03  1.16e-12 3.58e-01  3.15e-01     1s
#    6   2.10229266e+04  2.21420119e+03  4.15e-13 5.63e-02  9.91e-02     2s
#    7   8.24465125e+03  2.21693828e+03  2.23e-13 2.07e-02  3.04e-02     2s
#    8   3.80250387e+03  2.22028910e+03  9.84e-12 5.53e-03  7.80e-03     2s
#    9   2.37815301e+03  2.22058368e+03  2.44e-12 1.52e-03  7.72e-04     2s
#   10   2.22131284e+03  2.22093020e+03  1.35e-10 3.55e-13  1.87e-06     2s
#   11   2.22093278e+03  2.22093278e+03  1.64e-11 3.84e-13  2.75e-11     2s
#
# Barrier solved model in 11 iterations and 1.70 seconds (0.99 work units)
# Optimal objective 2.22093278e+03
#
# Crossover log...
#
#     3973 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.1837198e-11      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3974    2.2209328e+03   0.000000e+00   0.000000e+00      2s
#
# Solved with barrier
# Solved in 3974 iterations and 1.95 seconds (1.10 work units)
# Optimal objective  2.220932777e+03
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with

# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.0908475e+01   0.000000e+00   0.000000e+00      1s
#
# Solved with dual simplex
# Solved in 0 iterations and 1.00 seconds (0.50 work units)
# Optimal objective  9.090847511e+01
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_5879/1805981238.py:25: RuntimeWarning: invalid value encountered in sqrt
#   ucb = self.arm * self.hat_theta + self.beta * np.matrix(np.diag(np.sqrt( self.arm * inv_V * self.arm.T ))).T
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 207998 rows, 4000 columns and 411994 nonzeros
# Model fingerprint: 0x828e80fb
# Coefficient statistics:
#   Matrix range     [3e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 2e+00]
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Presolve removed 6239 rows and 2 columns
# Presolve removed 3 rows and 8967 columns
# Presolve time: 0.85s
# Presolved: 3997 rows, 199031 columns, 398060 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 5.993e+03
#  Factor NZ  : 6.784e+04 (roughly 80 MB of memory)
#  Factor Ops : 1.431e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -7.00029209e+05  1.42000807e+03  9.81e+01 1.65e+01  6.87e+01     1s
#    1  -1.08465846e+05  2.11764856e+03  2.68e+01 3.44e+01  2.90e+01     1s
#    2   2.81135653e+05  2.25948075e+03  5.40e-13 1.50e+01  1.20e+01     1s
#    3   1.92114271e+05  2.10916081e+03  7.41e-12 4.81e+00  3.87e+00     1s
#    4   1.29417042e+05  2.10764644e+03  4.06e-12 1.12e+00  1.20e+00     1s
#    5   8.60061657e+04  2.10896818e+03  1.91e-12 6.96e-01  6.93e-01     1s
#    6   6.78178456e+04  2.10951039e+03  2.61e-12 5.04e-01  4.96e-01     1s
#    7   5.05963974e+04  2.10992827e+03  3.09e-12 3.44e-01  3.34e-01     1s
#    8   4.50804041e+04  2.11103895e+03  2.64e-12 1.97e-01  2.63e-01     1s
#    9   2.55933772e+04  2.11184804e+03  1.15e-12 1.34e-01  1.38e-01     1s
#   10   1.71896848e+04  2.11587649e+03  1.16e-12 5.15e-02  8.11e-02     1s
#   11   1.00835400e+04  2.11905495e+03  7.36e-13 2.02e-02  4.13e-02     1s
#   12   3.29097468e+03  2.11960733e+03  2.76e-13 1.02e-02  6.00e-03     1s
#   13   2.23505680e+03  2.11976059e+03  5.63e-12 2.06e-03  5.83e-04     1s
#   14   2.12119160e+03  2.11980478e+03  1.23e-11 3.02e-06  6.97e-06     1s
#   15   2.11981131e+03  2.11980993e+03  6.11e-12 2.59e-13  6.97e-09     1s
#   16   2.11980993e+03  2.11980993e+03  1.55e-11 2.70e-13  6.99e-15     2s
#
# Barrier solved model in 16 iterations and 1.50 seconds (1.03 work units)
# Optimal objective 2.11980993e+03
#
# Crossover log...
#
#     3983 DPushes remaining with DInf 0.0000000e+00                 2s
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.7817303e-11      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3986    2.1198099e+03   0.000000e+00   0.000000e+00      2s
#
# Solved with barrier
# Solved in 3986 iterations and 1.72 seconds (1.15 work units)
# Optimal objective  2.119809931e+03

# %%
import pickle
with open("data.pkl", "wb") as f:
    pickle.dump((ucb_errors, linucb_errors), f)

# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy as np

def plot(errors, title):
    plt.clf()
    data = []
    for T in Ts:
        for num_arms in NumArmss:
            for ele in errors[T][num_arms]:
                data.append((T, num_arms, ele))
    x, y, z = zip(*data)
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    ax.set_title(title)
    ax.scatter(x,y,z)
    ax.set_xlabel("T")
    ax.set_ylabel("Num Arms")
    ax.set_zlabel("MSE")
    plt.show()

# %%
plot(ucb_errors, "UCB Prediction Error")

# %%
plot(linucb_errors, "LinUCB Prediction Error")
