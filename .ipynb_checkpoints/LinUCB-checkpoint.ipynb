# %%
import numpy as np
import math
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
from scipy.stats import truncnorm
import copy
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
class LinUCB():
    def __init__(self, arm, dim=2, lamda = 1, T=1000):
        self.arm = arm
        self.A_t = 0
        self.y = np.matrix(np.zeros((dim, 1)))
        self.V = np.matrix(lamda * np.identity(dim))
        self.lamda = lamda
        self.beta =  1 + np.sqrt(2*np.log(T)+dim*np.log((dim+T)/dim))
        self.actions = []
        self.T = T
        self.dim = dim
        self.action_idxs = []
        self.Vs = [copy.deepcopy(self.V)]
    def observe_reward(self, reward):
        
        self.V = self.V + self.arm[self.A_t].T * self.arm[self.A_t]
        self.Vs.append(copy.deepcopy(self.V))
        self.y = self.y + self.arm[self.A_t].T * reward
        
        
    def compute(self):
        inv_V = np.linalg.inv(self.V)
        self.hat_theta = inv_V * self.y
        ucb = self.arm * self.hat_theta + self.beta * np.matrix(np.diag(np.sqrt( self.arm * inv_V * self.arm.T ))).T
        self.A_t = np.argmax(ucb)
        self.actions.append(self.arm[self.A_t])
        self.action_idxs.append(self.A_t)
        return self.arm[self.A_t]

# %%
def Baseline1(alg):
    sample_means = np.random.rand(len(alg.sample_means))
    return sample_means

# %%
def Baseline2(alg):
    taus = [0] * alg.arm.shape[0]
    optimal_arm = alg.action_idxs[-1]
    num_pulls = {}
    for t, action in enumerate(alg.action_idxs):
        taus[action] = t

    for i in range(len(alg.arm)):
        num_pulls[i] = []

    for t in range(alg.T):
        for key in num_pulls.keys():
            if alg.action_idxs[t] != key:
                if t != 0:
                    num_pulls[key].append(num_pulls[key][ - 1])
                else:
                    num_pulls[key].append(0)
            else:
                if t != 0:
                    num_pulls[key].append(num_pulls[key][ - 1] + 1)
                else:
                    num_pulls[key].append(1)

    sample_means = []
    for idx, tau in enumerate(taus):
        if idx is not optimal_arm:
            sample_means.append(-2 * UCB.gcb(alg.T, alg.alpha, num_pulls[idx][tau]))
        else:
            sample_means.append(0)
    return np.asarray(sample_means)

# %%
class UCB:
    def __init__(self, action_set, dim=2, T=1000):
        self.arm = action_set
        self.T = T
        self.alpha = 1/(T**2)
        self.sample_means = np.asarray([0.0] * len(action_set))
        self.confidence_widths = np.asarray([np.inf] * len(action_set))
        self.num_pulls = np.asarray([0] * len(action_set))
        self.actions = []
        self.action_idxs = []
        self.dim = dim
        self.counter = 0
        self.debug_mean = {}
        self.debug_cw = {}
        self.debug_np = {}
        
    def compute(self):
        
        if self.counter < len(action_set):
            index = self.counter
        else:
            index = np.argmax(self.sample_means + self.confidence_widths)
        
        self.debug_mean[self.counter] = copy.deepcopy(self.sample_means)
        self.debug_cw[self.counter] = copy.deepcopy(self.confidence_widths)
        self.debug_np[self.counter] = copy.deepcopy(self.num_pulls)
        self.counter += 1
        self.num_pulls[index] += 1
        
        self.action_idxs.append(index)
        self.actions.append(self.arm[index])
        return self.arm[index]
    
    def observe_reward(self, reward):
        
        cur_mean = self.sample_means[self.action_idxs[-1]]
        num_samples = self.num_pulls[self.action_idxs[-1]] - 1
        new_mean = (cur_mean * num_samples + reward)/(num_samples + 1)
        self.sample_means[self.action_idxs[-1]] = new_mean
        self.confidence_widths[self.action_idxs[-1]] = self.gcb(self.T, self.alpha, num_samples + 1)
        
    @staticmethod
    def gcb(T, alpha, num_samples):
        return np.sqrt(2*(math.pow(T, alpha) - 1)/(alpha * num_samples))

# %%
def calc_pseudoregret(theta, actions):
    diff = theta - np.max(theta)
    new_actions = np.stack(actions, axis=0)
    return -np.sum(np.dot(new_actions, theta))

# %%
class Oracle:
    def __init__(self, theta, upper=1, lower=0):
        self.theta = theta
        self.upper = upper
        self.lower = lower
        
    def compute_reward(self, action):
        mu = np.inner(action, self.theta)
        sigma = .2
        X = truncnorm((self.lower - mu) / sigma, (self.upper - mu) / sigma, loc=mu, scale=sigma)
        return X.rvs(1)[0]

# %%
def train_alg(alg, T, theta, oracle):
    alg.actions = [0]
    reward = oracle.compute_reward(alg.arm[0])
    alg.observe_reward(reward)
    for time in range(T):
        action = alg.compute()
        reward = oracle.compute_reward(action)
        alg.observe_reward(reward)
        
def train_alg_UCB(alg, T, theta, oracle):
    for time in range(T):
        action = alg.compute()
        reward = oracle.compute_reward(action)
        alg.observe_reward(reward)

# %%
def generate_k_dim_vector(dim=2):
    full_index = random.randint(0,dim-1)
    vec = np.random.random(int(dim)) * 2 - 1
    vec[full_index] = np.sign(vec[full_index]) * 1
    return vec

def generate_random_vec(dim=2, mag=1):
    vec = np.random.random(int(dim))
    vec = vec/np.linalg.norm(vec)*mag
    return vec

# %%
def plot_vectors(theta, actions):
    plt.axis([-1, 1, -1, 1])
    plt.quiver(0, 0, theta[0], theta[1], color='green', scale=1)
    for idx, action in enumerate(actions):
        plt.quiver(0, 0, action[0], action[1], color = [(idx/len(actions), 0, 0)], scale=1)

# %%
#Change action set to boundaries
#Check how two thetas with same optimal actions will have different action sequences
#Why are these different? How will these differ?
#Choose different colors and figure out the scale
#check about frequency of "pulls", sum the action sequence!
#Candidate values of theta: alternating signs (like with 0.9, 0.5 as values, a lot of coordinates should differ), alternating signs with only one coord differs
#Exploratory: If you were just solving mab, can you formulat an alternative estimator that is a solution to an lp
#Exploratory: decision variables are unknown means where you have to solve, and every time an arm is pulled, you get a constraint
# You also get other constraints that when an arm is not pulled, you get an equality constraint
#so look at the end of the horizon, and get the lp from there

# %%
import gurobipy as gp

def estimate_ucb_means_lp(alg):
    m = gp.Model()
#     m.Params.LogToConsole = 0
    all_vars = {}
    num_pulls = {}
    T = alg.T
    for i in range(len(action_set)):
        num_pulls[i] = []

    for t in range(T):
        for key in num_pulls.keys():
            if alg.action_idxs[t] != key:
                if t != 0:
                    num_pulls[key].append(num_pulls[key][ - 1])
                else:
                    num_pulls[key].append(0)
            else:
                if t != 0:
                    num_pulls[key].append(num_pulls[key][ - 1] + 1)
                else:
                    num_pulls[key].append(1)

    for t in range(T):
        for idx, ele in enumerate(action_set):
            if t not in all_vars:
                all_vars[t] = {}
            all_vars[t][idx] = m.addVar(name="u_{}_{}".format(t, idx))

    expr = gp.LinExpr()
    list_of_all_vars = []
    for t in range(T-1,T):
        for i in range(len(action_set)):
            list_of_all_vars.append(all_vars[t][i])


    expr.addTerms([1.0] * len(list_of_all_vars), list_of_all_vars)

#     m.setObjective(expr, gp.GRB.MAXIMIZE)



    for t, ele in enumerate(alg.action_idxs):
        for i in range(len(action_set)):
            if i != ele and t >= len(action_set):
                m.addConstr(all_vars[t][ele] + UCB.gcb(T, alg.alpha, num_pulls[ele][t-1]) - all_vars[t][i] - UCB.gcb(T, alg.alpha, num_pulls[i][t - 1]) >= 0)
                if t + 1 < T:
                    m.addConstr(all_vars[t + 1][i] - all_vars[t][i] == 0)
            m.addConstr(all_vars[t][i] >= 0)
            m.addConstr(all_vars[t][i] <= 1)



    m.optimize()
    lp_vals = []
    for i in range(len(action_set)):
        lp_vals.append(all_vars[T-1][i].X)
        
    return lp_vals

# %%
def calc_Vs(alg):
    Vs = []
    Vs.append(alg.lamda * np.identity(alg.dim))
    for t in range(T):
        Vs.append(Vs[-1] + (alg.actions[t].T * alg.actions[t]))
    return(Vs)

def get_orthogonal_matrix(vec):
    first = np.identity(len(vec) - 1)
    second = -1 * vec[1:] / vec[0]

    others = np.concatenate((second, first),axis=0)

    banana = others @ (others.T @ others) @ others.T

    return banana

def estimate_linucb_means_lp(alg, normalize=True, tolerance=1e-5):
    m = gp.Model()
    m.Params.LogToConsole = 0
    all_vars = {}
    T = alg.T

    Vs = calc_Vs(alg)
    for t in range(alg.T):
        all_vars[t] = []
        for i in range(alg.dim):
            all_vars[t].append(m.addVar(name="y_{}_{}".format(t, i)))

    expr = gp.LinExpr()
    expr.addTerms([1.0] * len(all_vars[alg.T - 1]),all_vars[alg.T - 1])

#     m.setObjective(expr, gp.GRB.MAXIMIZE) 
    for t in range(T):
        for action in action_set:
            V = Vs[t]
            invV = np.linalg.inv(V)
            if action is not alg.actions[t]:
                expr = gp.LinExpr()

                mult = np.asarray(action @ invV)[0] * -1
                expr.addTerms(mult, all_vars[t])
                constant = np.sqrt(action @ invV @ action.T) * alg.beta * -1
                expr.addConstant(constant)

                opt_mult = np.asarray(alg.actions[t] @ invV)[0]
                expr.addTerms(opt_mult, all_vars[t])
                opt_constant = np.sqrt(alg.actions[t] @ invV @ alg.actions[t].T) * alg.beta
                expr.addConstant(opt_constant)

                m.addConstr(expr >= 0)

                
    for t in range(T):
        if t == T - 1:
            continue
        a_t = alg.actions[t]
        V_t = Vs[t]
        V_tplus1 = Vs[t+1]
        
        V_t_inv = np.linalg.pinv(V_t)
        V_tplus1_inv = np.linalg.pinv(V_tplus1)
        
        orthogonal_projection = get_orthogonal_matrix(V_t_inv @ a_t.T)
        first_coeff = np.asarray(orthogonal_projection @ V_tplus1_inv)
        second_coeff = np.asarray(orthogonal_projection @ V_t_inv)
        
        for curr_dim in range(first_coeff.shape[0]):
            firstexpr = gp.LinExpr()
            firstexpr.addTerms(first_coeff[curr_dim], all_vars[t+1])
            firstexpr.addTerms(-1 * second_coeff[curr_dim], all_vars[t])
            m.addConstr(firstexpr >= -1 * tolerance)
            m.addConstr(firstexpr <= tolerance)
            
        
    for i in range(alg.dim):
        m.addConstr(all_vars[0][i] == 0)



    for i in range(alg.dim):
        for t in range(alg.T):
            if t + 1 < alg.T:
                m.addConstr(all_vars[t][i] + 1 >= all_vars[t + 1][i])
                m.addConstr(all_vars[t][i] <= all_vars[t+1][i])

    m.optimize()

    final_Vinv = np.linalg.inv(Vs[-1])
    final_y = np.matrix([ele.X for ele in all_vars[alg.T - 1]]).T
    
    
    theta_estimate = np.linalg.inv(Vs[-1]) @ np.matrix(final_y)
    
    if normalize:
        theta_estimate = theta_estimate/np.linalg.norm(theta_estimate)
    return theta_estimate

# %%
def normalize_subopt(means):
    means = np.asarray(means)
    best_value = max(means)
    return best_value - means

def test_Baseline1(theta, action_set, T=1000):
    dim = theta.shape[-1]
    oracle = Oracle(theta)
    alg = UCB(action_set, T=T, dim=dim)
    train_alg_UCB(alg, T, theta, oracle)
    
    estimate_sample_means = normalize_subopt(Baseline1(alg))
    
    return mean_squared_error(normalize_subopt(alg.sample_means), estimate_sample_means)
    
def test_Baseline2(theta, action_set, T=1000):
    dim = theta.shape[-1]
    oracle = Oracle(theta)
    alg = UCB(action_set, T=T, dim=dim)
    train_alg_UCB(alg, T, theta, oracle)
    
    estimate_sample_means = normalize_subopt(Baseline2(alg))
    
    return mean_squared_error(normalize_subopt(alg.sample_means), estimate_sample_means)

# %%
def test_UCB(theta, action_set, T=1000):
    dim = theta.shape[-1]
    oracle = Oracle(theta)
    alg = UCB(action_set, T=T, dim=dim)
    train_alg_UCB(alg, T, theta, oracle)
    lp_vals = normalize_subopt(estimate_ucb_means_lp(alg))
    
    return mean_squared_error(normalize_subopt(alg.sample_means), lp_vals)
    
def test_LinUCB(theta, action_set, T=1000):
    oracle = Oracle(theta)
    dim = theta.shape[-1]
    alg = LinUCB(action_set, dim=dim, T=T)
    
    train_alg_UCB(alg, T, theta, oracle)
    
    true_means = normalize_subopt(action_set @ alg.hat_theta)
    theta_estimate = estimate_linucb_means_lp(alg)
    estimate_means = normalize_subopt(action_set @ theta_estimate)
    
    return mean_squared_error(true_means, estimate_means)

# %%
Ts =  [128, 256, 512, 1024, 2048]
NumArmss = [2, 8, 16, 32, 64, 128]
num_epochs = 10
ucb_errors = {}
linucb_errors = {}
baseline_1_errors = {}
baseline_2_errors = {}
for T in Ts:
    
    ucb_errors[T] = {}
    linucb_errors[T] = {}
    baseline_1_errors[T] = {}
    baseline_2_errors[T] = {}
    
    for num_arms in NumArmss:
        ucb_errors[T][num_arms] = []
        linucb_errors[T][num_arms] = []
        baseline_1_errors[T][num_arms] = []
        baseline_2_errors[T][num_arms] = []
        
        for _ in tqdm(range(num_epochs)):
            theta = np.matrix(generate_random_vec(dim = 2))
            action_set = np.matrix([generate_random_vec(dim = 2) for _ in range(num_arms)])
            
            ucb_error = test_UCB(theta, action_set, T=T)
            lin_ucb_error = test_LinUCB(theta, action_set, T=T)
            baseline_1_error = test_Baseline1(theta, action_set, T=T)
            baseline_2_error = test_Baseline2(theta, action_set, T=T)
            
            linucb_errors[T][num_arms].append(lin_ucb_error)
            ucb_errors[T][num_arms].append(ucb_error)
            baseline_1_errors[T][num_arms].append(baseline_1_error)
            baseline_2_errors[T][num_arms].append(baseline_2_error)
# Out:
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-01-28
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0x91e79bec
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-01, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0x34f9d3c9
# Coefficient statistics:
#   Matrix range     [4e-05, 3e+11]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 644 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 630 rows, 524 columns, 2030 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.586021e+05   0.000000e+00      0s
#      520    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 520 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Warning: unscaled primal violation = 0.00493622 and residual = 7.10352e-05
#  10%|████▍                                       | 1/10 [00:00<00:05,  1.56it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0x5d725258
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0x7e27df80
# Coefficient statistics:
#   Matrix range     [2e-03, 5e+05]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Presolve removed 763 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 511 rows, 628 columns, 1658 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.491414e-01   0.000000e+00      0s
#      400    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 400 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  20%|████████▊                                   | 2/10 [00:01<00:04,  1.62it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0x92ee4c9b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-03, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0x7a91efc9
# Coefficient statistics:
#   Matrix range     [6e-03, 6e+06]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 761 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 513 rows, 625 columns, 1665 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.366057e-01   0.000000e+00      0s
#      374    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 374 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  30%|█████████████▏                              | 3/10 [00:01<00:04,  1.61it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0x10cdded9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-01, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0x5f04c7d1
# Coefficient statistics:
#   Matrix range     [8e-04, 9e+06]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 763 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 511 rows, 628 columns, 1658 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.028395e-01   0.000000e+00      0s
#      371    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 371 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  40%|█████████████████▌                          | 4/10 [00:02<00:03,  1.56it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0xd28aaeed
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-02, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0x9a447734
# Coefficient statistics:
#   Matrix range     [2e-02, 6e+07]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 760 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 514 rows, 624 columns, 1668 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.467982e-01   0.000000e+00      0s
#      363    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 363 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  50%|██████████████████████                      | 5/10 [00:03<00:03,  1.55it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0xd20cf1cf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-02, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0x4a7e8a8c
# Coefficient statistics:
#   Matrix range     [1e-02, 3e+11]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 669 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 605 rows, 555 columns, 1963 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.031957e+02   0.000000e+00      0s
# Warning: Markowitz tolerance tightened to 0.5
# Extra simplex iterations after uncrush: 9
#      402    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 402 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Warning: unscaled primal violation = 0.000488281 and residual = 0.000966562
#  60%|██████████████████████████▍                 | 6/10 [00:03<00:02,  1.54it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0x9756d9a0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-03, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0xe1d6ec3b
# Coefficient statistics:
#   Matrix range     [2e-02, 2e+05]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 757 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 517 rows, 622 columns, 1676 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.491241e-01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      370    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 370 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  70%|██████████████████████████████▊             | 7/10 [00:04<00:01,  1.56it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0x942802f3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-02, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0x751fcf2a
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+10]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-16, 1e+00]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 742 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 532 rows, 609 columns, 1723 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.988982e-01   0.000000e+00      0s
# Warning: Markowitz tolerance tightened to 0.5
# Extra simplex iterations after uncrush: 1
#      364    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 364 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  80%|███████████████████████████████████▏        | 8/10 [00:05<00:01,  1.53it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0xcd61e853
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e-03, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0x43bbcc7d
# Coefficient statistics:
#   Matrix range     [2e-03, 2e+07]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 757 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 517 rows, 622 columns, 1676 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.094179e-01   0.000000e+00      0s
#      368    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 368 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  90%|███████████████████████████████████████▌    | 9/10 [00:05<00:00,  1.58it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 763 rows, 256 columns and 1014 nonzeros
# Model fingerprint: 0x4b4e9c64
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-02, 1e+00]
# Presolve removed 763 rows and 256 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1274 rows, 256 columns and 3306 nonzeros
# Model fingerprint: 0xc93ce8e7
# Coefficient statistics:
#   Matrix range     [5e-04, 5e+02]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-16, 1e+00]
# Presolve removed 766 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 508 rows, 630 columns, 1650 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.393128e-01   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      373    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 373 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# 100%|███████████████████████████████████████████| 10/10 [00:06<00:00,  1.58it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0x8b9f51da
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0x7f915609
# Coefficient statistics:
#   Matrix range     [4e-06, 2e+05]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 761 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 1281 rows, 609 columns, 3217 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.759839e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 3
#      442    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 442 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
#  10%|████▍                                       | 1/10 [00:00<00:06,  1.35it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0x974cddf0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0xcbe13bf6
# Coefficient statistics:
#   Matrix range     [6e-05, 4e+06]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 731 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 1311 rows, 579 columns, 3307 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.046525e+05   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      518    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 518 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
#  20%|████████▊                                   | 2/10 [00:01<00:06,  1.33it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0x7de2434b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0xa7a8d3ea
# Coefficient statistics:
#   Matrix range     [1e-03, 3e+02]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 771 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 1271 rows, 618 columns, 3188 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.326266e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 2
#      421    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 421 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
#  30%|█████████████▏                              | 3/10 [00:02<00:05,  1.37it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0x373b1529
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0xc97d2e6f
# Coefficient statistics:
#   Matrix range     [3e-04, 2e+06]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 2e+00]
# Presolve removed 764 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 1278 rows, 616 columns, 3202 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.263410e+02   0.000000e+00      0s
#      381    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 381 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  40%|█████████████████▌                          | 4/10 [00:02<00:04,  1.46it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0x1931d9b7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0xdbd07dab
# Coefficient statistics:
#   Matrix range     [1e-03, 1e+06]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 782 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 1260 rows, 629 columns, 3155 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.044251e-01   0.000000e+00      0s
#      407    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 407 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
#  50%|██████████████████████                      | 5/10 [00:03<00:03,  1.48it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0xf2851842
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e-03, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0x48c5815b
# Coefficient statistics:
#   Matrix range     [2e-04, 2e+15]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 747 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 1295 rows, 603 columns, 3257 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.911365e+05   0.000000e+00      0s
# Extra simplex iterations after uncrush: 2
#      611    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 611 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
# Warning: unscaled primal violation = 0.000244141 and residual = 0.25001
#  60%|██████████████████████████▍                 | 6/10 [00:04<00:02,  1.47it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0xeda2ba35
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0x90fd364d
# Coefficient statistics:
#   Matrix range     [2e-04, 2e+02]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 789 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 1253 rows, 632 columns, 3138 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.507342e-01   0.000000e+00      0s
#      425    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 425 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
#  70%|██████████████████████████████▊             | 7/10 [00:04<00:02,  1.47it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0x8663618f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0xe99ef32d
# Coefficient statistics:
#   Matrix range     [5e-04, 8e+09]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 699 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 1343 rows, 551 columns, 3403 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.192914e+03   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      592    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 592 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
#  80%|███████████████████████████████████▏        | 8/10 [00:05<00:01,  1.44it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0x63c53d55
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0xd5fddf1f
# Coefficient statistics:
#   Matrix range     [6e-04, 4e+04]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e-05, 1e+00]
# Presolve removed 768 rows and 2 columns
# Presolve time: 0.00s
# Presolved: 1274 rows, 617 columns, 3195 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.034289e+02   0.000000e+00      0s
#      515    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 515 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
#  90%|███████████████████████████████████████▌    | 9/10 [00:06<00:00,  1.40it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3721 rows, 1024 columns and 5394 nonzeros
# Model fingerprint: 0xc70cf112
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e-02, 1e+00]
# Presolve removed 3721 rows and 1024 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 2042 rows, 256 columns and 4842 nonzeros
# Model fingerprint: 0x5b6e7c4a
# Coefficient statistics:
#   Matrix range     [6e-04, 3e+02]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 773 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 1269 rows, 621 columns, 3181 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.340132e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 5
#      496    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 496 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
# 100%|███████████████████████████████████████████| 10/10 [00:07<00:00,  1.41it/s]
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7441 rows, 2048 columns and 10786 nonzeros
# Model fingerprint: 0x8f8df17c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 7441 rows and 2048 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3066 rows, 256 columns and 6890 nonzeros
# Model fingerprint: 0x057b08a1
# Coefficient statistics:
#   Matrix range     [2e-05, 5e+04]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 784 rows and 2 columns
# Presolve time: 0.02s
# Presolved: 2282 rows, 609 columns, 5219 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.534914e+02   0.000000e+00      0s
#      452    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 452 iterations and 0.03 seconds (0.02 work units)
# Optimal objective  0.000000000e+00
#  10%|████▍                                       | 1/10 [00:00<00:08,  1.05it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7441 rows, 2048 columns and 10786 nonzeros
# Model fingerprint: 0x0f26fbe7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 7441 rows and 2048 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3066 rows, 256 columns and 6890 nonzeros
# Model fingerprint: 0xb8ae760e
# Coefficient statistics:
#   Matrix range     [7e-05, 1e+06]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 739 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 2327 rows, 569 columns, 5349 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.009167e+04   0.000000e+00      0s
#      558    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 558 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  0.000000000e+00
#  20%|████████▊                                   | 2/10 [00:01<00:07,  1.10it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7441 rows, 2048 columns and 10786 nonzeros
# Model fingerprint: 0xa13102b8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-02, 1e+00]
# Presolve removed 7441 rows and 2048 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3066 rows, 256 columns and 6890 nonzeros
# Model fingerprint: 0x8465e2c4
# Coefficient statistics:
#   Matrix range     [7e-04, 9e+04]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 800 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 2266 rows, 630 columns, 5166 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.310022e+00   0.000000e+00      0s
#      458    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 458 iterations and 0.03 seconds (0.02 work units)
# Optimal objective  0.000000000e+00
#  30%|█████████████▏                              | 3/10 [00:02<00:06,  1.06it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7441 rows, 2048 columns and 10786 nonzeros
# Model fingerprint: 0xfe82dd3a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-02, 1e+00]
# Presolve removed 7441 rows and 2048 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3066 rows, 256 columns and 6890 nonzeros
# Model fingerprint: 0xfb844fcb
# Coefficient statistics:
#   Matrix range     [1e-04, 5e+04]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Presolve removed 746 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 2320 rows, 582 columns, 5322 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.335881e+02   0.000000e+00      0s
# Extra simplex iterations after uncrush: 1
#      459    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 459 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  0.000000000e+00
#  40%|█████████████████▌                          | 4/10 [00:03<00:05,  1.09it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7441 rows, 2048 columns and 10786 nonzeros
# Model fingerprint: 0xf0467f01
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e-02, 1e+00]
# Presolve removed 7441 rows and 2048 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3066 rows, 256 columns and 6890 nonzeros
# Model fingerprint: 0xa271e1e0
# Coefficient statistics:
#   Matrix range     [1e-04, 2e+09]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e-16, 1e+00]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 754 rows and 2 columns
# Presolve time: 0.02s
# Presolved: 2312 rows, 592 columns, 5300 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   5.797953e+04   0.000000e+00      0s
#      428    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 428 iterations and 0.03 seconds (0.02 work units)
# Optimal objective  0.000000000e+00
#  50%|██████████████████████                      | 5/10 [00:04<00:04,  1.11it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7441 rows, 2048 columns and 10786 nonzeros
# Model fingerprint: 0xc5261ed2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 7441 rows and 2048 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3066 rows, 256 columns and 6890 nonzeros
# Model fingerprint: 0xa2613c03
# Coefficient statistics:
#   Matrix range     [3e-06, 1e+08]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 772 rows and 2 columns
# Presolve time: 0.02s
# Presolved: 2294 rows, 597 columns, 5255 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.469566e+04   0.000000e+00      0s
#      463    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 463 iterations and 0.03 seconds (0.02 work units)
# Optimal objective  0.000000000e+00
#  60%|██████████████████████████▍                 | 6/10 [00:05<00:03,  1.11it/s]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 7441 rows, 2048 columns and 10786 nonzeros
# Model fingerprint: 0x01de9259
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e-02, 1e+00]
# Presolve removed 7441 rows and 2048 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  0.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3066 rows, 256 columns and 6890 nonzeros
# Model fingerprint: 0x9a4b4338
# Coefficient statistics:
#   Matrix range     [5e-04, 5e+17]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e-16, 1e+00]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 744 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 2322 rows, 582 columns, 5330 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.891578e+04   0.000000e+00      0s
#
# Solved in 321 iterations and 0.02 seconds (0.01 work units)
# Infeasible model
#  60%|██████████████████████████▍                 | 6/10 [00:06<00:04,  1.00s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/3504580157.py in <module>
#      24
#      25             ucb_error = test_UCB(theta, action_set, T=T)
# ---> 26             lin_ucb_error = test_LinUCB(theta, action_set, T=T)
#      27             baseline_1_error = test_Baseline1(theta, action_set, T=T)
#      28             baseline_2_error = test_Baseline2(theta, action_set, T=T)
#
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/3977694199.py in test_LinUCB(theta, action_set, T)
#      16
#      17     true_means = normalize_subopt(action_set @ alg.hat_theta)
# ---> 18     theta_estimate = estimate_linucb_means_lp(alg)
#      19     estimate_means = normalize_subopt(action_set @ theta_estimate)
#      20
#
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/1069695921.py in estimate_linucb_means_lp(alg, normalize, tolerance)
#      88
#      89     final_Vinv = np.linalg.inv(Vs[-1])
# ---> 90     final_y = np.matrix([ele.X for ele in all_vars[alg.T - 1]]).T
#      91
#      92
#
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/1069695921.py in <listcomp>(.0)
#      88
#      89     final_Vinv = np.linalg.inv(Vs[-1])
# ---> 90     final_y = np.matrix([ele.X for ele in all_vars[alg.T - 1]]).T
#      91
#      92
#
# src/gurobipy/var.pxi in gurobipy.Var.__getattr__()
#
# src/gurobipy/var.pxi in gurobipy.Var.getAttr()
#
# src/gurobipy/attrutil.pxi in gurobipy.__getattr()
#
# AttributeError: Unable to retrieve attribute 'X'

# %%
print(linucb_errors)
print(ucb_errors)
print(baseline_1_errors)
print(baseline_2_errors)
# Out:
# {128: {2: [0.02641498855503693, 0.05000245141828733, 5.3640983662106455e-05, 0.061523649604570727, 1.8342479831104956e-08, 0.005386281698067514, 0.004074641483852514, 0.006336949321084432, 0.00045033096511597643, 0.03217530506894938]}}
# {128: {2: [0.00018012928331509687, 0.000443089596404987, 0.5000384014314105, 3.8014609489396107e-08, 6.31476643636246e-05, 0.007549706998078728, 0.4700873990191725, 0.2638999042857955, 0.5000781958470403, 0.3182562786702555]}}
# {128: {2: [0.023785803480789607, 0.15589837266431264, 0.0025549232251341324, 0.0003281613562260454, 0.143108726249327, 0.010474790390711159, 0.016307613789094694, 0.13050901352702055, 0.002309204223198178, 0.16332446337594878]}}
# {128: {2: [0.0030926221598676835, 0.0005569094662268097, 1.0080621093669758e-06, 0.0030652559667006126, 3.438626125649187e-05, 0.011804252784628348, 0.0023274669341368233, 0.020810825554355667, 0.00012486210002405905, 0.029287718094711878]}}

# %%
import pickle
with open("data.pkl", "wb") as f:
    pickle.dump((ucb_errors, linucb_errors, baseline_1_errors, baseline_2_errors), f)

# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy as np
import pickle
Ts =  [128, 256, 512, 1024, 2048]
NumArmss = [2, 8, 16, 32, 64, 128]
def plot(errors, title, remove_outliers=False):
    plt.clf()
    data = []
    for T in Ts:
        for num_arms in NumArmss:
            for ele in errors[T][num_arms]:
                if not remove_outliers or ele < 20:
                    data.append((T, num_arms, ele))
                    
    x, y, z = zip(*data)
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    ax.set_title(title)
    ax.scatter(x,y,z)
    ax.set_xlabel("T")
    ax.set_ylabel("Num Arms")
    ax.set_zlabel("MSE")
    plt.savefig("linucb.png")
    plt.show()

def plot_many(errors_list, names, title, remove_outliers=False):
    plt.clf()
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    ax.set_title(title)
    
    colors = ['tab:blue', 'tab:orange', 'tab:green', "tab:red"]
    for idx, errors in enumerate(errors_list):
    
        data = []
        for T in Ts:
            for num_arms in NumArmss:
                for ele in errors[T][num_arms]:
                    if not remove_outliers or ele < 20:
                        data.append((T, num_arms, ele))

        x, y, z = zip(*data)
        ax.scatter(x,y,z, c=colors[idx], label=names[idx])
    ax.legend()
    ax.set_xlabel("T")
    ax.set_ylabel("Num Arms")
    ax.set_zlabel("MSE")
    plt.savefig("linucb.png")
    plt.show()

# %%
plot(ucb_errors, "UCB Prediction Error")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/3400061557.py in <module>
# ----> 1 plot(ucb_errors, "UCB Prediction Error")
#
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/2017084948.py in plot(errors, title, remove_outliers)
#      11     for T in Ts:
#      12         for num_arms in NumArmss:
# ---> 13             for ele in errors[T][num_arms]:
#      14                 if not remove_outliers or ele < 20:
#      15                     data.append((T, num_arms, ele))
#
# KeyError: 8

# %%
plot(linucb_errors, "LinUCB Prediction Error")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/4086306410.py in <module>
# ----> 1 plot(linucb_errors, "LinUCB Prediction Error")
#
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/2017084948.py in plot(errors, title, remove_outliers)
#      11     for T in Ts:
#      12         for num_arms in NumArmss:
# ---> 13             for ele in errors[T][num_arms]:
#      14                 if not remove_outliers or ele < 20:
#      15                     data.append((T, num_arms, ele))
#
# KeyError: 8

# %%
plot(baseline_1_errors, "Baseline 1 Error")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/2505924125.py in <module>
# ----> 1 plot(baseline_1_errors, "Baseline 1 Error")
#
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/2017084948.py in plot(errors, title, remove_outliers)
#      11     for T in Ts:
#      12         for num_arms in NumArmss:
# ---> 13             for ele in errors[T][num_arms]:
#      14                 if not remove_outliers or ele < 20:
#      15                     data.append((T, num_arms, ele))
#
# KeyError: 8

# %%
plot(baseline_2_errors, "Baseline 2 Error", remove_outliers=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/2530933168.py in <module>
# ----> 1 plot(baseline_2_errors, "Baseline 2 Error", remove_outliers=True)
#
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/2017084948.py in plot(errors, title, remove_outliers)
#      11     for T in Ts:
#      12         for num_arms in NumArmss:
# ---> 13             for ele in errors[T][num_arms]:
#      14                 if not remove_outliers or ele < 20:
#      15                     data.append((T, num_arms, ele))
#
# KeyError: 8

# %%
plot_many([linucb_errors, ucb_errors, baseline_1_errors, baseline_2_errors], ["LinUCB LP", "UCB LP", "Baseline 1", "Baseline 2"], "All", remove_outliers=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/3341630589.py in <module>
# ----> 1 plot_many([linucb_errors, ucb_errors, baseline_1_errors, baseline_2_errors], ["LinUCB LP", "UCB LP", "Baseline 1", "Baseline 2"], "All", remove_outliers=True)
#
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_34593/2017084948.py in plot_many(errors_list, names, title, remove_outliers)
#      38         for T in Ts:
#      39             for num_arms in NumArmss:
# ---> 40                 for ele in errors[T][num_arms]:
#      41                     if not remove_outliers or ele < 20:
#      42                         data.append((T, num_arms, ele))
#
# KeyError: 8

# %%
vec = np.asarray([41,1,341])

def get_orthogonal_matrix(vec):
    first = np.identity(len(vec) - 1)
    second = -1 * np.expand_dims(vec[1:], axis=0) / vec[0]

    others = np.concatenate((second, first),axis=0)

    banana = others @ (others.T @ others) @ others.T

    return banana

# %%
print(baseline_1_errors)
# Out:
# {128: {2: [0.11811419647315978, 0.006471613285499168, 0.032244446268327405, 0.04992393406598355, 0.0032489711463628518, 0.00045385225745159447, 9.879509384609865e-05, 0.004783803547495503, 0.003685803507197123, 0.06892979186045092]}}
