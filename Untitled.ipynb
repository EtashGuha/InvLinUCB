# %%
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
with open("data.pkl", "rb") as f:
    ucb_errors, lin_ucb_errors = pickle.load(f)

# %%
data = []
Ts = [10, 50, 100, 500, 1000, 2000]
NumArmss = [2, 5, 10, 20, 50, 100]
for T in Ts:
    for num_arms in NumArmss:
        for ele in lin_ucb_errors[T][num_arms]:
            data.append((T, num_arms, ele))
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.set_title("LinUCB Prediction Error")
ax.scatter(x,y,z)
ax.set_xlabel("T")
ax.set_ylabel("Num Arms")
ax.set_zlabel("MSE")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j0/12_hmkfx6bx04_ymlhscx4t80000gp/T/ipykernel_14305/364474772.py in <module>
#       9 ax = fig.add_subplot(projection='3d')
#      10 ax.set_title("LinUCB Prediction Error")
# ---> 11 ax.scatter(x,y,z)
#      12 ax.set_xlabel("T")
#      13 ax.set_ylabel("Num Arms")
#
# NameError: name 'x' is not defined
